# %% [markdown]
# # Award Recipients

# %% [markdown]
# ### Objective: Fetch all award recipients from USASpending.
# #### Filter by amount greater than X.
# - Currently x = $0.00
# - This dataset includes contractors and other entities that have been awarded funds from the federal government.
# - The dataset is ~176K rows as of 11/20/2024
# - Note: Award types (P,C,R) filter out child award (C) records to prevent duplicates for awards (P,R) records are saved.
# #### Dataset Details
# - Output .csv file for portability
# - Columns, this data can be used by other APIs that require a type of id for more details.
#     - id, UUID of recipient at the recipient_level
#     - duns, DUNS id (Data Universal Numbering System),can be blank/null if not provided
#     - uei, Recipients UEI (Unique Entity Identifier) null when not provided
#         - Note: can be used to validate data in source system via website search
#     - name, Name of recipient, null if not provided
#     - recipient_level, Enum letter representing level. P=Parent, C=Child, R=Neither P or C
#     - amount, Sum of all monetary value for all transactions associated with recipient for trailing 12 months
#     - date_fetched, Added to results by fetch function date records retrieved from API.

# %% [markdown]
# ## Technical Details

# %% [markdown]
# ### Remote APIs
# - Data is fetched from USA Spending APIs
# - Documentation can be found at
#     - ```https://api.usaspending.gov/```
#     - Technical documentation resources
#         - ```https://api.usaspending.gov/docs/endpoints```
#         - ```https://github.com/fedspendingtransparency/usaspending-api```
#         - API in use documentation
#         - ```https://github.com/fedspendingtransparency/usaspending-api/blob/master/usaspending_api/api_contracts/contracts/v2/recipient.md```
# - The data is public no API key is required.
#     - Use of a key is handled in code, for now it can be ```DEMO_KEY```
#     - If the api is changed and requires a key use a proper key value.
# - API in use
#     - ```https://api.usaspending.gov/api/v2/recipient/```

# %% [markdown]
# ### Functions & Parameter Notes
# - The ```fetch_paginated_data``` function appends data to a csv file.
# - The function uses pagination and a retry loops to deal with rate limits.
# - Default values
#     - ```fetch_paginated_data(api_url, params, api_key, limit=100, max_pages=10, output_file="government_contractors.csv", retries=5, delay=5)```
# - Example execution
#     - ```fetch_paginated_data(api_url, params, api_key, 1000, 1000)```
# - Notes
#     - Logic
#         - Processing will stop when a page of results has a summed amount of $0.00.
#         - There may be a few records with a $0.00 amount value at from the last page based on page size.
#         - e.g. Pulling 1000 records/page the last x records can be $0.00.
#     - Execution Time
#         - A timer tracks how long execution takes.
#         - In testing this was in 5 minute range, ymmv.

# %% [markdown]
# # Imports

# %%
import csv
import os
import pandas as pd
import time
from datetime import datetime

import requests
from requests.exceptions import RequestException, Timeout

# %% [markdown]
# # Functions

# %%
def fetch_paginated_data(api_url = 'NA', params = {}, api_key = 'DEMO_KEY', limit=100, max_pages=10, output_file="federal_government_awardees.csv", page_amount_min = 0.0, retries=5, delay=5):
    """
    Fetch data from the USASpending API with pagination and write to a CSV file incrementally.
    Includes API key for authentication in the headers.
    
    :param api_url: The API endpoint URL (e.g., 'https://api.usaspending.gov/api/v2/recipient/')
    :param params: A dictionary containing filters or additional query parameters.
    :param api_key: Your USASpending API key to use for authentication.
    :param limit: Number of records to fetch per page (default is 100).
    :param max_pages: Maximum number of pages to fetch (default is 10).
    :param output_file: Name of the CSV file to save the results (default is 'federal_government_awardees.csv').
    :return: None
    """
    # Record the start time of the process
    start_time = time.time()
    
    #all_results = []
    total_amount = 0.0
    page = 1  # Start at the first page
    
    # Get the current directory where the script is running
    current_directory = os.getcwd()
    
    # Define the full path for the output file
    output_path = os.path.join(current_directory, output_file)
    
    # Define headers with API key for authentication
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    # Initialize sum requirement variable to min amount
    # ensure we run through the loop one time.
    page_amount_sum = page_amount_min
    
    # Get the current date
    current_date = datetime.now().strftime('%Y-%m-%d')
    
    while page <= max_pages:

        attempt = 0
        while attempt < retries:

            # Add pagination parameters to the request
            params.update({"limit": limit, "page": page})

            # Make the API request with headers
            try:
                response = requests.post(api_url, json=params, headers=headers)
                response.raise_for_status()  # Raise an exception for HTTP errors
                
                # Parse the JSON response
                data = response.json()
                results = data.get("results", [])
                
                # If there are no results, stop paginating
                if not results:
                    print(f"No more results on page {page}. Ending pagination.")
                    break
                
                # Add the current date to each record
                for record in results:
                    record["date_fetched"] = current_date
                
                # Filter out all 'C' records (those with recipient_level = 'C')
                filtered_results = [result for result in results if result.get('recipient_level') != 'C']

                # Sum the 'amount' field for the current page
                page_amount_sum = sum(result.get('amount', 0.0) for result in filtered_results)
                total_amount += page_amount_sum
                
                print(f"Page {page}: Sum of 'amount' for this page: {page_amount_sum}")
                
                if page_amount_sum > page_amount_min:
                    # Open the CSV file in append mode to add data incrementally
                    with open(output_path, mode='a', newline='', encoding='utf-8') as file:
                        # Create a CSV DictWriter object
                        writer = csv.DictWriter(file, fieldnames=filtered_results[0].keys())
                        
                        # Write the header only if the file is empty (on the first page)
                        if file.tell() == 0:
                            writer.writeheader()
                        
                        # Write the data (current page results)
                        writer.writerows(filtered_results)
                    
                    print(f"Fetched and wrote page {page} with {len(filtered_results)} records.")
                else:
                    print(f"Page {page}: Sum of 'amount' for this page: {page_amount_sum} " +
                          f"is less than the minimum amount requirement of {page_amount_min}" +
                          f", skipping csv write.")
                
                page += 1  # Increment to fetch the next page
                   
            except (RequestException, Timeout) as e:
                print(f"Error occurred on attempt {attempt} for page {page}: {e}")
                sleep_time = delay * attempt
                attempt += 1
                if attempt < retries:
                    print(f"Retrying in {delay} seconds...")
                    time.sleep(sleep_time)  # Wait before retrying
                else:
                    print(f"Max retries reached for page {page}. Moving to next page.")
                    break
            
            # Retry loop exit cases
            if (page_amount_sum <= page_amount_min):
                break

            if page >= max_pages + 1:
                break
        
        # Pagination loop exit cases
        if (page_amount_sum <= page_amount_min):
            break

        if page >= max_pages + 1:
            break
        
    print(f"Total Amount is {total_amount}.")                
    print(f"Results are being saved to {output_path}")
    
    # Record the end time and calculate the elapsed time
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Process completed in {elapsed_time:.2f} seconds")

# %% [markdown]
# # Execution Example

# %%
# Parameters 
api_url = "https://api.usaspending.gov/api/v2/recipient/"
params = {
   # "filters": {"some api parameter": ["the value"]}  # Example filter (optional)
      # filters are not used but are available see api documentation.
      # page number and limit are in use as parameters.
}
api_key = "DEMO_KEY"  # Replace with your actual API key when needed
fetch_paginated_data(api_url, params, api_key, 1000, 1000, "federal_government_awardees.csv", 0.0)
# Out:
# Page 1: Sum of 'amount' for this page: 1544592320628.671
# Fetched and wrote page 1 with 640 records.
# Page 2: Sum of 'amount' for this page: 129365480322.77994
# Fetched and wrote page 2 with 604 records.
# Page 3: Sum of 'amount' for this page: 66280520424.809975
# Fetched and wrote page 3 with 603 records.
# Page 4: Sum of 'amount' for this page: 43199333046.79999
# Fetched and wrote page 4 with 598 records.
# Page 5: Sum of 'amount' for this page: 31153705095.54998
# Fetched and wrote page 5 with 585 records.
# Page 6: Sum of 'amount' for this page: 24846870969.98999
# Fetched and wrote page 6 with 592 records.
# Page 7: Sum of 'amount' for this page: 20642142348.429993
# Fetched and wrote page 7 with 601 records.
# Page 8: Sum of 'amount' for this page: 17461534679.700024
# Fetched and wrote page 8 with 599 records.
# Page 9: Sum of 'amount' for this page: 14911428799.960018
# Fetched and wrote page 9 with 593 records.
# Page 10: Sum of 'amount' for this page: 13271292134.290005
# Fetched and wrote page 10 with 607 records.
# Page 11: Sum of 'amount' for this page: 11457609480.669992
# Fetched and wrote page 11 with 593 records.
# Page 12: Sum of 'amount' for this page: 10278401538.850006
# Fetched and wrote page 12 with 597 records.
# Page 13: Sum of 'amount' for this page: 9349523731.839998
# Fetched and wrote page 13 with 605 records.
# Page 14: Sum of 'amount' for this page: 8305838338.649998
# Fetched and wrote page 14 with 593 records.
# Page 15: Sum of 'amount' for this page: 7493922730.299994
# Fetched and wrote page 15 with 586 records.
# Page 16: Sum of 'amount' for this page: 7156904536.539998
# Fetched and wrote page 16 with 614 records.
# Page 17: Sum of 'amount' for this page: 6501814092.330001
# Fetched and wrote page 17 with 610 records.
# Page 18: Sum of 'amount' for this page: 5967789104.869993
# Fetched and wrote page 18 with 607 records.
# Page 19: Sum of 'amount' for this page: 5533686143.789996
# Fetched and wrote page 19 with 608 records.
# Page 20: Sum of 'amount' for this page: 5093212777.370001
# Fetched and wrote page 20 with 602 records.
# Page 21: Sum of 'amount' for this page: 5007421692.5199995
# Fetched and wrote page 21 with 637 records.
# Page 22: Sum of 'amount' for this page: 4614992555.289997
# Fetched and wrote page 22 with 629 records.
# Page 23: Sum of 'amount' for this page: 4317919545.760002
# Fetched and wrote page 23 with 629 records.
# Page 24: Sum of 'amount' for this page: 4001736772.2700014
# Fetched and wrote page 24 with 622 records.
# Page 25: Sum of 'amount' for this page: 3712664092.87
# Fetched and wrote page 25 with 616 records.
# Page 26: Sum of 'amount' for this page: 3691060323.0800037
# Fetched and wrote page 26 with 652 records.
# Page 27: Sum of 'amount' for this page: 3315739506.06
# Fetched and wrote page 27 with 621 records.
# Page 28: Sum of 'amount' for this page: 3138035319.850001
# Fetched and wrote page 28 with 622 records.
# Page 29: Sum of 'amount' for this page: 3048552474.909998
# Fetched and wrote page 29 with 638 records.
# Page 30: Sum of 'amount' for this page: 2857909060.4200006
# Fetched and wrote page 30 with 632 records.
# Page 31: Sum of 'amount' for this page: 2752324946.6900005
# Fetched and wrote page 31 with 643 records.
# Page 32: Sum of 'amount' for this page: 2635830803.4100018
# Fetched and wrote page 32 with 651 records.
# Page 33: Sum of 'amount' for this page: 2502171564.360001
# Fetched and wrote page 33 with 650 records.
# Page 34: Sum of 'amount' for this page: 2306545600.770001
# Fetched and wrote page 34 with 631 records.
# Page 35: Sum of 'amount' for this page: 2181394658.9099984
# Fetched and wrote page 35 with 626 records.
# Page 36: Sum of 'amount' for this page: 2172847678.8700004
# Fetched and wrote page 36 with 653 records.
# Page 37: Sum of 'amount' for this page: 1985400506.070001
# Fetched and wrote page 37 with 628 records.
# Page 38: Sum of 'amount' for this page: 1936286278.979999
# Fetched and wrote page 38 with 641 records.
# Page 39: Sum of 'amount' for this page: 1876170959.4299998
# Fetched and wrote page 39 with 648 records.
# Page 40: Sum of 'amount' for this page: 1736902932.3999984
# Fetched and wrote page 40 with 629 records.
# Page 41: Sum of 'amount' for this page: 1732036213.2799995
# Fetched and wrote page 41 with 658 records.
# Page 42: Sum of 'amount' for this page: 1685541292.65
# Fetched and wrote page 42 with 670 records.
# Page 43: Sum of 'amount' for this page: 1543844508.4599996
# Fetched and wrote page 43 with 641 records.
# Page 44: Sum of 'amount' for this page: 1498353452.6299996
# Fetched and wrote page 44 with 649 records.
# Page 45: Sum of 'amount' for this page: 1440138757.7500012
# Fetched and wrote page 45 with 651 records.
# Page 46: Sum of 'amount' for this page: 1371642714.6400006
# Fetched and wrote page 46 with 646 records.
# Page 47: Sum of 'amount' for this page: 1364668919.5199995
# Fetched and wrote page 47 with 670 records.
# Page 48: Sum of 'amount' for this page: 1316608946.3699994
# Fetched and wrote page 48 with 666 records.
# Page 49: Sum of 'amount' for this page: 1236935299.1500008
# Fetched and wrote page 49 with 649 records.
# Page 50: Sum of 'amount' for this page: 1220837169.5999987
# Fetched and wrote page 50 with 666 records.
# Page 51: Sum of 'amount' for this page: 1189847951.1599996
# Fetched and wrote page 51 with 673 records.
# Page 52: Sum of 'amount' for this page: 1107481114.69
# Fetched and wrote page 52 with 651 records.
# Page 53: Sum of 'amount' for this page: 1076826593.8700008
# Fetched and wrote page 53 with 658 records.
# Page 54: Sum of 'amount' for this page: 1057834390.6300004
# Fetched and wrote page 54 with 672 records.
# Page 55: Sum of 'amount' for this page: 982225407.6599998
# Fetched and wrote page 55 with 646 records.
# Page 56: Sum of 'amount' for this page: 986507212.470001
# Fetched and wrote page 56 with 668 records.
# Page 57: Sum of 'amount' for this page: 950925439.9099997
# Fetched and wrote page 57 with 668 records.
# Page 58: Sum of 'amount' for this page: 908046966.2600003
# Fetched and wrote page 58 with 661 records.
# Page 59: Sum of 'amount' for this page: 853555138.9899999
# Fetched and wrote page 59 with 645 records.
# Page 60: Sum of 'amount' for this page: 821346910.28
# Fetched and wrote page 60 with 642 records.
# Page 61: Sum of 'amount' for this page: 794339591.1600006
# Fetched and wrote page 61 with 640 records.
# Page 62: Sum of 'amount' for this page: 818396438.6999999
# Fetched and wrote page 62 with 681 records.
# Page 63: Sum of 'amount' for this page: 774840398.0900002
# Fetched and wrote page 63 with 668 records.
# Page 64: Sum of 'amount' for this page: 738450050.9799997
# Fetched and wrote page 64 with 658 records.
# Page 65: Sum of 'amount' for this page: 723517937.6699996
# Fetched and wrote page 65 with 667 records.
# Page 66: Sum of 'amount' for this page: 714782605.6100004
# Fetched and wrote page 66 with 682 records.
# Page 67: Sum of 'amount' for this page: 675751010.5899998
# Fetched and wrote page 67 with 667 records.
# Page 68: Sum of 'amount' for this page: 755497814.2899997
# Fetched and wrote page 68 with 757 records.
# Page 69: Sum of 'amount' for this page: 673406398.2500005
# Fetched and wrote page 69 with 691 records.
# Page 70: Sum of 'amount' for this page: 640191750.2499996
# Fetched and wrote page 70 with 677 records.
# Page 71: Sum of 'amount' for this page: 613628958.7900002
# Fetched and wrote page 71 with 669 records.
# Page 72: Sum of 'amount' for this page: 616935085.4299995
# Fetched and wrote page 72 with 692 records.
# Page 73: Sum of 'amount' for this page: 575613746.9799998
# Fetched and wrote page 73 with 666 records.
# Page 74: Sum of 'amount' for this page: 563802642.9399996
# Fetched and wrote page 74 with 671 records.
# Page 75: Sum of 'amount' for this page: 545627552.3400002
# Fetched and wrote page 75 with 670 records.
# Page 76: Sum of 'amount' for this page: 546009898.5000001
# Fetched and wrote page 76 with 689 records.
# Page 77: Sum of 'amount' for this page: 517759699.8699998
# Fetched and wrote page 77 with 675 records.
# Page 78: Sum of 'amount' for this page: 518448318.57000005
# Fetched and wrote page 78 with 694 records.
# Page 79: Sum of 'amount' for this page: 480603428.3100004
# Fetched and wrote page 79 with 661 records.
# Page 80: Sum of 'amount' for this page: 481523848.36999995
# Fetched and wrote page 80 with 682 records.
# Page 81: Sum of 'amount' for this page: 461126401.48999995
# Fetched and wrote page 81 with 673 records.
# Page 82: Sum of 'amount' for this page: 447825105.44
# Fetched and wrote page 82 with 674 records.
# Page 83: Sum of 'amount' for this page: 443926171.3899999
# Fetched and wrote page 83 with 687 records.
# Page 84: Sum of 'amount' for this page: 430832742.3499999
# Fetched and wrote page 84 with 687 records.
# Page 85: Sum of 'amount' for this page: 421969775.71999997
# Fetched and wrote page 85 with 694 records.
# Page 86: Sum of 'amount' for this page: 399569719.49
# Fetched and wrote page 86 with 674 records.
# Page 87: Sum of 'amount' for this page: 389465169.5599999
# Fetched and wrote page 87 with 676 records.
# Page 88: Sum of 'amount' for this page: 379091231.58000016
# Fetched and wrote page 88 with 677 records.
# Page 89: Sum of 'amount' for this page: 377046731.7400002
# Fetched and wrote page 89 with 692 records.
# Page 90: Sum of 'amount' for this page: 359957558.0899999
# Fetched and wrote page 90 with 680 records.
# Page 91: Sum of 'amount' for this page: 348958246.94000024
# Fetched and wrote page 91 with 679 records.
# Page 92: Sum of 'amount' for this page: 360530331.3899999
# Fetched and wrote page 92 with 719 records.
# Page 93: Sum of 'amount' for this page: 336479342.1599999
# Fetched and wrote page 93 with 678 records.
# Page 94: Sum of 'amount' for this page: 313368961.54000014
# Fetched and wrote page 94 with 649 records.
# Page 95: Sum of 'amount' for this page: 321307895.91
# Fetched and wrote page 95 with 684 records.
# Page 96: Sum of 'amount' for this page: 310545031.85999995
# Fetched and wrote page 96 with 681 records.
# Page 97: Sum of 'amount' for this page: 303640840.33000004
# Fetched and wrote page 97 with 683 records.
# Page 98: Sum of 'amount' for this page: 295139009.5500005
# Fetched and wrote page 98 with 683 records.
# Page 99: Sum of 'amount' for this page: 283452191.4900001
# Fetched and wrote page 99 with 675 records.
# Page 100: Sum of 'amount' for this page: 277660571.9700002
# Fetched and wrote page 100 with 680 records.
# Page 101: Sum of 'amount' for this page: 281767490.7800002
# Fetched and wrote page 101 with 706 records.
# Page 102: Sum of 'amount' for this page: 275947775.36
# Fetched and wrote page 102 with 708 records.
# Page 103: Sum of 'amount' for this page: 259065355.4300001
# Fetched and wrote page 103 with 684 records.
# Page 104: Sum of 'amount' for this page: 246434342.91999996
# Fetched and wrote page 104 with 667 records.
# Page 105: Sum of 'amount' for this page: 239501413.4900002
# Fetched and wrote page 105 with 667 records.
# Page 106: Sum of 'amount' for this page: 243688557.5300001
# Fetched and wrote page 106 with 696 records.
# Page 107: Sum of 'amount' for this page: 236078658.75000003
# Fetched and wrote page 107 with 690 records.
# Page 108: Sum of 'amount' for this page: 222407474.0800001
# Fetched and wrote page 108 with 668 records.
# Page 109: Sum of 'amount' for this page: 219237643.63999996
# Fetched and wrote page 109 with 676 records.
# Page 110: Sum of 'amount' for this page: 217225983.2
# Fetched and wrote page 110 with 688 records.
# Page 111: Sum of 'amount' for this page: 212862676.57000008
# Fetched and wrote page 111 with 692 records.
# Page 112: Sum of 'amount' for this page: 210841108.36000007
# Fetched and wrote page 112 with 701 records.
# Page 113: Sum of 'amount' for this page: 211277745.27999997
# Fetched and wrote page 113 with 714 records.
# Page 114: Sum of 'amount' for this page: 197779472.71
# Fetched and wrote page 114 with 685 records.
# Page 115: Sum of 'amount' for this page: 200100870.2800001
# Fetched and wrote page 115 with 711 records.
# Page 116: Sum of 'amount' for this page: 204673528.05000007
# Fetched and wrote page 116 with 743 records.
# Page 117: Sum of 'amount' for this page: 183477522.14000008
# Fetched and wrote page 117 with 680 records.
# Page 118: Sum of 'amount' for this page: 178333665.50000003
# Fetched and wrote page 118 with 679 records.
# Page 119: Sum of 'amount' for this page: 170624043.73
# Fetched and wrote page 119 with 666 records.
# Page 120: Sum of 'amount' for this page: 174234292.03999987
# Fetched and wrote page 120 with 695 records.
# Page 121: Sum of 'amount' for this page: 165383737.41999996
# Fetched and wrote page 121 with 669 records.
# Page 122: Sum of 'amount' for this page: 167524557.35999998
# Fetched and wrote page 122 with 694 records.
# Page 123: Sum of 'amount' for this page: 158724264.05000007
# Fetched and wrote page 123 with 673 records.
# Page 124: Sum of 'amount' for this page: 154028311.60999984
# Fetched and wrote page 124 with 669 records.
# Page 125: Sum of 'amount' for this page: 151817050.5999999
# Fetched and wrote page 125 with 675 records.
# Page 126: Sum of 'amount' for this page: 145486610.0199999
# Fetched and wrote page 126 with 662 records.
# Page 127: Sum of 'amount' for this page: 144915604.7899999
# Fetched and wrote page 127 with 675 records.
# Page 128: Sum of 'amount' for this page: 137566539.77
# Fetched and wrote page 128 with 656 records.
# Page 129: Sum of 'amount' for this page: 135186821.31999996
# Fetched and wrote page 129 with 660 records.
# Page 130: Sum of 'amount' for this page: 148093980.26000002
# Fetched and wrote page 130 with 739 records.
# Page 131: Sum of 'amount' for this page: 131658453.95999998
# Fetched and wrote page 131 with 666 records.
# Page 132: Sum of 'amount' for this page: 130065720.19999996
# Fetched and wrote page 132 with 674 records.
# Page 133: Sum of 'amount' for this page: 123157875.30000007
# Fetched and wrote page 133 with 654 records.
# Page 134: Sum of 'amount' for this page: 120780200.55000004
# Fetched and wrote page 134 with 656 records.
# Page 135: Sum of 'amount' for this page: 112420476.54
# Fetched and wrote page 135 with 625 records.
# Page 136: Sum of 'amount' for this page: 119988090.66999999
# Fetched and wrote page 136 with 683 records.
# Page 137: Sum of 'amount' for this page: 113695102.79999998
# Fetched and wrote page 137 with 662 records.
# Page 138: Sum of 'amount' for this page: 113698334.76999998
# Fetched and wrote page 138 with 678 records.
# Page 139: Sum of 'amount' for this page: 105842567.11000003
# Fetched and wrote page 139 with 647 records.
# Page 140: Sum of 'amount' for this page: 101951819.11999997
# Fetched and wrote page 140 with 638 records.
# Page 141: Sum of 'amount' for this page: 100967267.31
# Fetched and wrote page 141 with 647 records.
# Page 142: Sum of 'amount' for this page: 99206328.6200001
# Fetched and wrote page 142 with 652 records.
# Page 143: Sum of 'amount' for this page: 97230911.2
# Fetched and wrote page 143 with 650 records.
# Page 144: Sum of 'amount' for this page: 95296702.40000007
# Fetched and wrote page 144 with 651 records.
# Page 145: Sum of 'amount' for this page: 90536709.02
# Fetched and wrote page 145 with 634 records.
# Page 146: Sum of 'amount' for this page: 88036072.83000001
# Fetched and wrote page 146 with 631 records.
# Page 147: Sum of 'amount' for this page: 87368539.77000001
# Fetched and wrote page 147 with 642 records.
# Page 148: Sum of 'amount' for this page: 85504174.80999999
# Fetched and wrote page 148 with 645 records.
# Page 149: Sum of 'amount' for this page: 80581154.31999998
# Fetched and wrote page 149 with 624 records.
# Page 150: Sum of 'amount' for this page: 88050197.4
# Fetched and wrote page 150 with 700 records.
# Page 151: Sum of 'amount' for this page: 88270028.78999999
# Fetched and wrote page 151 with 709 records.
# Page 152: Sum of 'amount' for this page: 77464805.34999998
# Fetched and wrote page 152 with 637 records.
# Page 153: Sum of 'amount' for this page: 75632261.38
# Fetched and wrote page 153 with 636 records.
# Page 154: Sum of 'amount' for this page: 72538982.16999997
# Fetched and wrote page 154 with 626 records.
# Page 155: Sum of 'amount' for this page: 70864244.82000002
# Fetched and wrote page 155 with 628 records.
# Page 156: Sum of 'amount' for this page: 70637984.52
# Fetched and wrote page 156 with 641 records.
# Page 157: Sum of 'amount' for this page: 66678068.32000004
# Fetched and wrote page 157 with 620 records.
# Page 158: Sum of 'amount' for this page: 66271491.250000015
# Fetched and wrote page 158 with 633 records.
# Page 159: Sum of 'amount' for this page: 71124594.02999999
# Fetched and wrote page 159 with 695 records.
# Page 160: Sum of 'amount' for this page: 70134315.86999999
# Fetched and wrote page 160 with 700 records.
# Page 161: Sum of 'amount' for this page: 64992395.06999996
# Fetched and wrote page 161 with 656 records.
# Page 162: Sum of 'amount' for this page: 61586002.49
# Fetched and wrote page 162 with 636 records.
# Page 163: Sum of 'amount' for this page: 58414923.750000015
# Fetched and wrote page 163 with 618 records.
# Page 164: Sum of 'amount' for this page: 56885043.050000034
# Fetched and wrote page 164 with 617 records.
# Page 165: Sum of 'amount' for this page: 56624638.37999999
# Fetched and wrote page 165 with 630 records.
# Page 166: Sum of 'amount' for this page: 54794116.90000002
# Fetched and wrote page 166 with 625 records.
# Page 167: Sum of 'amount' for this page: 54100746.05999997
# Fetched and wrote page 167 with 633 records.
# Page 168: Sum of 'amount' for this page: 55276983.519999996
# Fetched and wrote page 168 with 664 records.
# Page 169: Sum of 'amount' for this page: 51154958.86000001
# Fetched and wrote page 169 with 632 records.
# Page 170: Sum of 'amount' for this page: 49631389.60999999
# Fetched and wrote page 170 with 627 records.
# Page 171: Sum of 'amount' for this page: 49484934.87000001
# Fetched and wrote page 171 with 642 records.
# Page 172: Sum of 'amount' for this page: 47106988.38000002
# Fetched and wrote page 172 with 626 records.
# Page 173: Sum of 'amount' for this page: 45224360.39000001
# Fetched and wrote page 173 with 610 records.
# Page 174: Sum of 'amount' for this page: 44802261.54000001
# Fetched and wrote page 174 with 621 records.
# Page 175: Sum of 'amount' for this page: 44558090.429999985
# Fetched and wrote page 175 with 634 records.
# Page 176: Sum of 'amount' for this page: 42059659.79999998
# Fetched and wrote page 176 with 613 records.
# Page 177: Sum of 'amount' for this page: 41386333.26999999
# Fetched and wrote page 177 with 620 records.
# Page 178: Sum of 'amount' for this page: 41092731.11000001
# Fetched and wrote page 178 with 632 records.
# Page 179: Sum of 'amount' for this page: 39036351.2
# Fetched and wrote page 179 with 616 records.
# Page 180: Sum of 'amount' for this page: 38311675.02000003
# Fetched and wrote page 180 with 621 records.
# Page 181: Sum of 'amount' for this page: 38435671.00000001
# Fetched and wrote page 181 with 639 records.
# Page 182: Sum of 'amount' for this page: 36655503.22
# Fetched and wrote page 182 with 624 records.
# Page 183: Sum of 'amount' for this page: 36305888.71000002
# Fetched and wrote page 183 with 636 records.
# Page 184: Sum of 'amount' for this page: 34731291.45000002
# Fetched and wrote page 184 with 625 records.
# Page 185: Sum of 'amount' for this page: 33255350.75999997
# Fetched and wrote page 185 with 613 records.
# Page 186: Sum of 'amount' for this page: 32814295.980000004
# Fetched and wrote page 186 with 620 records.
# Page 187: Sum of 'amount' for this page: 31890657.020000003
# Fetched and wrote page 187 with 618 records.
# Page 188: Sum of 'amount' for this page: 33545275.59999999
# Fetched and wrote page 188 with 668 records.
# Page 189: Sum of 'amount' for this page: 31493758.359999996
# Fetched and wrote page 189 with 633 records.
# Page 190: Sum of 'amount' for this page: 29692078.14999999
# Fetched and wrote page 190 with 611 records.
# Page 191: Sum of 'amount' for this page: 28708656.070000026
# Fetched and wrote page 191 with 606 records.
# Page 192: Sum of 'amount' for this page: 28975313.839999996
# Fetched and wrote page 192 with 628 records.
# Page 193: Sum of 'amount' for this page: 27712669.069999993
# Fetched and wrote page 193 with 616 records.
# Page 194: Sum of 'amount' for this page: 26924176.07999998
# Fetched and wrote page 194 with 614 records.
# Page 195: Sum of 'amount' for this page: 25788771.089999985
# Fetched and wrote page 195 with 606 records.
# Page 196: Sum of 'amount' for this page: 25520077.51000001
# Fetched and wrote page 196 with 616 records.
# Page 197: Sum of 'amount' for this page: 25679302.73000001
# Fetched and wrote page 197 with 637 records.
# Page 198: Sum of 'amount' for this page: 25030429.130000025
# Fetched and wrote page 198 with 631 records.
# Page 199: Sum of 'amount' for this page: 22882545.569999997
# Fetched and wrote page 199 with 592 records.
# Page 200: Sum of 'amount' for this page: 22989579.340000007
# Fetched and wrote page 200 with 611 records.
# Page 201: Sum of 'amount' for this page: 22380409.550000004
# Fetched and wrote page 201 with 612 records.
# Page 202: Sum of 'amount' for this page: 22011639.369999997
# Fetched and wrote page 202 with 619 records.
# Page 203: Sum of 'amount' for this page: 22244937.57000002
# Fetched and wrote page 203 with 640 records.
# Page 204: Sum of 'amount' for this page: 20980004.340000004
# Fetched and wrote page 204 with 621 records.
# Page 205: Sum of 'amount' for this page: 19816229.66999999
# Fetched and wrote page 205 with 604 records.
# Page 206: Sum of 'amount' for this page: 19312296.850000005
# Fetched and wrote page 206 with 606 records.
# Page 207: Sum of 'amount' for this page: 19118941.04
# Fetched and wrote page 207 with 618 records.
# Page 208: Sum of 'amount' for this page: 20289573.24000001
# Fetched and wrote page 208 with 674 records.
# Page 209: Sum of 'amount' for this page: 18045720.28999999
# Fetched and wrote page 209 with 607 records.
# Page 210: Sum of 'amount' for this page: 17058056.010000005
# Fetched and wrote page 210 with 590 records.
# Page 211: Sum of 'amount' for this page: 16796617.87
# Fetched and wrote page 211 with 598 records.
# Page 212: Sum of 'amount' for this page: 16868187.880000003
# Fetched and wrote page 212 with 618 records.
# Page 213: Sum of 'amount' for this page: 16468502.970000003
# Fetched and wrote page 213 with 621 records.
# Page 214: Sum of 'amount' for this page: 15267282.750000006
# Fetched and wrote page 214 with 593 records.
# Page 215: Sum of 'amount' for this page: 16579871.180000002
# Fetched and wrote page 215 with 661 records.
# Page 216: Sum of 'amount' for this page: 15636517.099999998
# Fetched and wrote page 216 with 628 records.
# Page 217: Sum of 'amount' for this page: 14559898.339999998
# Fetched and wrote page 217 with 599 records.
# Page 218: Sum of 'amount' for this page: 14180853.709999999
# Fetched and wrote page 218 with 599 records.
# Page 219: Sum of 'amount' for this page: 13916933.740000008
# Fetched and wrote page 219 with 605 records.
# Page 220: Sum of 'amount' for this page: 13443029.770000007
# Fetched and wrote page 220 with 602 records.
# Page 221: Sum of 'amount' for this page: 13101444.029999988
# Fetched and wrote page 221 with 604 records.
# Page 222: Sum of 'amount' for this page: 12679721.350000003
# Fetched and wrote page 222 with 603 records.
# Page 223: Sum of 'amount' for this page: 12606019.470000004
# Fetched and wrote page 223 with 619 records.
# Page 224: Sum of 'amount' for this page: 14340179.65
# Fetched and wrote page 224 with 717 records.
# Page 225: Sum of 'amount' for this page: 11790586.830000004
# Fetched and wrote page 225 with 596 records.
# Page 226: Sum of 'amount' for this page: 11514608.780000001
# Fetched and wrote page 226 with 600 records.
# Page 227: Sum of 'amount' for this page: 11185109.739999995
# Fetched and wrote page 227 with 601 records.
# Page 228: Sum of 'amount' for this page: 10671140.359999998
# Fetched and wrote page 228 with 592 records.
# Page 229: Sum of 'amount' for this page: 10040038.009999989
# Fetched and wrote page 229 with 574 records.
# Page 230: Sum of 'amount' for this page: 10150529.529999994
# Fetched and wrote page 230 with 599 records.
# Page 231: Sum of 'amount' for this page: 9774613.08
# Fetched and wrote page 231 with 597 records.
# Page 232: Sum of 'amount' for this page: 9580057.709999997
# Fetched and wrote page 232 with 604 records.
# Page 233: Sum of 'amount' for this page: 9177522.340000004
# Fetched and wrote page 233 with 600 records.
# Page 234: Sum of 'amount' for this page: 9978752.609999996
# Fetched and wrote page 234 with 666 records.
# Page 235: Sum of 'amount' for this page: 8660321.350000007
# Fetched and wrote page 235 with 592 records.
# Page 236: Sum of 'amount' for this page: 8323354.770000003
# Fetched and wrote page 236 with 588 records.
# Page 237: Sum of 'amount' for this page: 8055016.770000002
# Fetched and wrote page 237 with 589 records.
# Page 238: Sum of 'amount' for this page: 7776911.050000002
# Fetched and wrote page 238 with 591 records.
# Page 239: Sum of 'amount' for this page: 7486575.880000001
# Fetched and wrote page 239 with 590 records.
# Page 240: Sum of 'amount' for this page: 7165832.019999994
# Fetched and wrote page 240 with 586 records.
# Page 241: Sum of 'amount' for this page: 6957934.740000006
# Fetched and wrote page 241 with 587 records.
# Page 242: Sum of 'amount' for this page: 6692468.669999997
# Fetched and wrote page 242 with 586 records.
# Page 243: Sum of 'amount' for this page: 6590115.259999998
# Fetched and wrote page 243 with 600 records.
# Page 244: Sum of 'amount' for this page: 6386058.139999999
# Fetched and wrote page 244 with 604 records.
# Page 245: Sum of 'amount' for this page: 6791617.500000002
# Fetched and wrote page 245 with 667 records.
# Page 246: Sum of 'amount' for this page: 7149455.7200000025
# Fetched and wrote page 246 with 715 records.
# Page 247: Sum of 'amount' for this page: 5863896.760000002
# Fetched and wrote page 247 with 602 records.
# Page 248: Sum of 'amount' for this page: 5847548.610000001
# Fetched and wrote page 248 with 633 records.
# Page 249: Sum of 'amount' for this page: 5406770.159999995
# Fetched and wrote page 249 with 619 records.
# Page 250: Sum of 'amount' for this page: 5113542.800000002
# Fetched and wrote page 250 with 623 records.
# Page 251: Sum of 'amount' for this page: 4810679.000000003
# Fetched and wrote page 251 with 622 records.
# Page 252: Sum of 'amount' for this page: 4583845.190000002
# Fetched and wrote page 252 with 634 records.
# Page 253: Sum of 'amount' for this page: 4248765.650000002
# Fetched and wrote page 253 with 629 records.
# Page 254: Sum of 'amount' for this page: 3860705.579999999
# Fetched and wrote page 254 with 618 records.
# Page 255: Sum of 'amount' for this page: 3593359.1100000017
# Fetched and wrote page 255 with 619 records.
# Page 256: Sum of 'amount' for this page: 3781511.1100000036
# Fetched and wrote page 256 with 698 records.
# Page 257: Sum of 'amount' for this page: 4949187.25
# Fetched and wrote page 257 with 963 records.
# Page 258: Sum of 'amount' for this page: 4732636.810000002
# Fetched and wrote page 258 with 923 records.
# Page 259: Sum of 'amount' for this page: 3220230.75
# Fetched and wrote page 259 with 654 records.
# Page 260: Sum of 'amount' for this page: 3123475.2199999993
# Fetched and wrote page 260 with 680 records.
# Page 261: Sum of 'amount' for this page: 3099962.580000002
# Fetched and wrote page 261 with 737 records.
# Page 262: Sum of 'amount' for this page: 2599955.2600000016
# Fetched and wrote page 262 with 673 records.
# Page 263: Sum of 'amount' for this page: 2392249.2200000025
# Fetched and wrote page 263 with 683 records.
# Page 264: Sum of 'amount' for this page: 2177376.8200000017
# Fetched and wrote page 264 with 695 records.
# Page 265: Sum of 'amount' for this page: 2040096.8399999992
# Fetched and wrote page 265 with 736 records.
# Page 266: Sum of 'amount' for this page: 1629444.3600000034
# Fetched and wrote page 266 with 668 records.
# Page 267: Sum of 'amount' for this page: 1518839.1400000013
# Fetched and wrote page 267 with 737 records.
# Page 268: Sum of 'amount' for this page: 1245216.9100000022
# Fetched and wrote page 268 with 756 records.
# Page 269: Sum of 'amount' for this page: 923621.0300000003
# Fetched and wrote page 269 with 738 records.
# Page 270: Sum of 'amount' for this page: 633197.3599999998
# Fetched and wrote page 270 with 700 records.
# Page 271: Sum of 'amount' for this page: 406837.1600000005
# Fetched and wrote page 271 with 724 records.
# Page 272: Sum of 'amount' for this page: 156119.16000000003
# Fetched and wrote page 272 with 688 records.
# Page 273: Sum of 'amount' for this page: 5017.500000000002
# Fetched and wrote page 273 with 890 records.
# Page 274: Sum of 'amount' for this page: 0.0
# Page 274: Sum of 'amount' for this page: 0.0 is less than the minimum amount requirement of 0.0, skipping csv write.
# Total Amount is 2098018524827.3242.
# Results are being saved to c:\Users\dj\OneDrive\Documents\root\lds\Projects\open-data-project\AwardRecipients\federal_government_awardees.csv
# Process completed in 254.98 seconds
